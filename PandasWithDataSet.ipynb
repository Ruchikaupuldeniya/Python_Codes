# %%
#same location data set

# %%
import pandas as pd

# %%
data = pd.read_csv('weather.csv')

# %%
data
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
# show the dataset shape

# %%
data.shape
# Out:
# (366, 22)

# %%
#remove the one colum

# %%
del data['Cloud3pm']

# %%
data
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity9am  \
# 0             30.0         SW         NW           6.0  ...           68
# ...

# %%
#using drop

# %%
data.drop(columns = ['Cloud3pm'])

# %%
#getting the column value

# %%
data[['MinTemp','MaxTemp','Rainfall']]
# Out:
#      MinTemp  MaxTemp  Rainfall
# 0        8.0     24.3       0.0
# 1       14.0     26.9       3.6
# 2       13.7     23.4       3.6
# 3       13.3     15.5      39.8
# 4        7.6     16.1       2.8
# ..       ...      ...       ...
# 361      9.0     30.7       0.0
# 362      7.1     28.4       0.0
# 363     12.5     19.9       0.0
# 364     12.5     26.9       0.0
# 365     12.3     30.2       0.0
#
# [366 rows x 3 columns]

# %%
data.count()
# Out:
# MinTemp          366
# MaxTemp          366
# Rainfall         366
# Evaporation      366
# Sunshine         363
# WindGustDir      363
# WindGustSpeed    364
# WindDir9am       335
# WindDir3pm       365
# WindSpeed9am     359
# WindSpeed3pm     366
# Humidity9am      366
# Humidity3pm      366
# Pressure9am      366
# Pressure3pm      366
# Cloud9am         366
# Temp9am          366
# Temp3pm          366
# RainToday        366
# RISK_MM          366
# RainTomorrow     366
# dtype: int64

# %%
data.Maxtemp = data.MaxTemp.fillna(data.MaxTemp.mean())
# Out:
# C:\Users\2021icts80\AppData\Local\Temp\ipykernel_4588\3111259206.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   data.Maxtemp = data.MaxTemp.fillna(data.MaxTemp.mean())

# %%
data.head(20)
# Out:
#     MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0       8.0     24.3       0.0          3.4       6.3          NW
# 1      14.0     26.9       3.6          4.4       9.7         ENE
# 2      13.7     23.4       3.6          5.8       3.3          NW
# 3      13.3     15.5      39.8          7.2       9.1          NW
# 4       7.6     16.1       2.8          5.6      10.6         SSE
# 5       6.2     16.9       0.0          5.8       8.2          SE
# 6       6.1     18.2       0.2          4.2       8.4          SE
# 7       8.3     17.0       0.0          5.6       4.6           E
# 8       8.8     19.5       0.0          4.0       4.1           S
# 9       8.4     22.8      16.2          5.4       7.7           E
# 10      9.1     25.2       0.0          4.2      11.9           N
# 11      8.5     27.3       0.2          7.2      12.5           E
# 12     10.1     27.9       0.0          7.2      13.0         WNW
# ...

# %%
data['MaxTemp']>45
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 361    False
# 362    False
# 363    False
# 364    False
# 365    False
# Name: MaxTemp, Length: 366, dtype: bool

# %%
condition = data['MaxTemp']>4
filter = data[condition]
filter
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity9am  \
# 0             30.0         SW         NW           6.0  ...           68
# ...

# %%
data.describe()
# Out:
#           MinTemp     MaxTemp    Rainfall  Evaporation    Sunshine  \
# count  366.000000  366.000000  366.000000   366.000000  363.000000
# mean     7.265574   20.550273    1.428415     4.521858    7.909366
# std      6.025800    6.690516    4.225800     2.669383    3.481517
# min     -5.300000    7.600000    0.000000     0.200000    0.000000
# 25%      2.300000   15.025000    0.000000     2.200000    5.950000
# 50%      7.450000   19.650000    0.000000     4.200000    8.600000
# 75%     12.500000   25.500000    0.200000     6.400000   10.500000
# max     20.900000   35.800000   39.800000    13.800000   13.600000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count     364.000000    359.000000    366.000000   366.000000   366.000000
# mean       39.840659      9.651811     17.986339    72.035519    44.519126
# std        13.059807      7.951929      8.856997    13.137058    16.850947
# ...

# %%
import matplotlib.pyplot as plt

x = range(len(data))
y1 = data['MaxTemp']
y2 = data['MinTemp']

plt.plot(x, y1, label='MaxTemp')
plt.plot(x, y2, label='MinTemp')

plt.legend()
plt.show()
